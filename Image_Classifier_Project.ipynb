# %% [markdown]
# <a href="https://colab.research.google.com/github/DrigoDomingos/Codes_Support/blob/master/Image_Classifier_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'
# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision

# %%
#!pip3 install http://download.pytorch.org/whl/cu80/torch-0.4.0.post4-cp36-cp36m-linux_x86_64.whl 
# !pip install torchvision

#!pip install torch==0.4.0
#!pip install torchvision
# !pip install numpy
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.2.1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (5.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchvision) (0.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.14.6)

# %%
# Imports here
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import transforms as T
from torchvision import datasets, transforms, models

# %%
# !pip install Pillow
# !apt-get install python-dev
#!pip3 install PIL
#!pip install PIL
# !pip install image
import image
#import PIL.image
from PIL import Image
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (5.4.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-dev is already the newest version (2.7.15~rc1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# Requirement already satisfied: image in /usr/local/lib/python3.6/dist-packages (1.5.27)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from image) (5.4.0)
# Requirement already satisfied: django in /usr/local/lib/python3.6/dist-packages (from image) (2.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from django->image) (2018.7)

# %%
# !python -V
# Out:
# Python 3.6.7

# %%
# !wget -cq https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip 
# !wget -cq https://raw.githubusercontent.com/udacity/pytorch_challenge/master/cat_to_name.json
# !rm -r flower_data || true
# !unzip -qq flower_data.zip

# %%
print(torch.__version__)
# Out:
# 0.4.0

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). You can [download the data here](https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip). The dataset is split into two parts, training and validation. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. If you use a pre-trained network, you'll also need to make sure the input data is resized to 224x224 pixels as required by the networks.
#
# The validation set is used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks available from `torchvision` were trained on the ImageNet dataset where each color channel was normalized separately. For both sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %%
# TODO: Define your transforms for the training and validation sets
train_transforms = transforms.Compose([transforms.Resize(299),
                                       transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(299),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])]) 

test_transforms = transforms.Compose([transforms.Resize(299),
                                      transforms.CenterCrop(299),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])]) 

# TODO: Load the datasets with ImageFolder 
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
test_data = datasets.ImageFolder(valid_dir, transform=test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
cat_to_name
# Out:
# {'1': 'pink primrose',
#  '10': 'globe thistle',
#  '100': 'blanket flower',
#  '101': 'trumpet creeper',
#  '102': 'blackberry lily',
#  '11': 'snapdragon',
#  '12': "colt's foot",
#  '13': 'king protea',
#  '14': 'spear thistle',
#  '15': 'yellow iris',
#  '16': 'globe-flower',
#  '17': 'purple coneflower',
#  '18': 'peruvian lily',
#  '19': 'balloon flower',
#  '2': 'hard-leaved pocket orchid',
#  '20': 'giant white arum lily',
#  '21': 'fire lily',
#  '22': 'pincushion flower',
#  '23': 'fritillary',
#  '24': 'red ginger',
#  '25': 'grape hyacinth',
#  '26': 'corn poppy',
#  '27': 'prince of wales feathers',
#  '28': 'stemless gentian',
#  '29': 'artichoke',
#  '3': 'canterbury bells',
#  '30': 'sweet william',
#  '31': 'carnation',
#  '32': 'garden phlox',
#  '33': 'love in the mist',
#  '34': 'mexican aster',
#  '35': 'alpine sea holly',
#  '36': 'ruby-lipped cattleya',
#  '37': 'cape flower',
#  '38': 'great masterwort',
#  '39': 'siam tulip',
#  '4': 'sweet pea',
#  '40': 'lenten rose',
#  '41': 'barbeton daisy',
#  '42': 'daffodil',
#  '43': 'sword lily',
#  '44': 'poinsettia',
#  '45': 'bolero deep blue',
#  '46': 'wallflower',
#  '47': 'marigold',
#  '48': 'buttercup',
#  '49': 'oxeye daisy',
#  '5': 'english marigold',
#  '50': 'common dandelion',
#  '51': 'petunia',
#  '52': 'wild pansy',
#  '53': 'primula',
#  '54': 'sunflower',
#  '55': 'pelargonium',
#  '56': 'bishop of llandaff',
#  '57': 'gaura',
#  '58': 'geranium',
#  '59': 'orange dahlia',
#  '6': 'tiger lily',
#  '60': 'pink-yellow dahlia',
#  '61': 'cautleya spicata',
#  '62': 'japanese anemone',
#  '63': 'black-eyed susan',
#  '64': 'silverbush',
#  '65': 'californian poppy',
#  '66': 'osteospermum',
#  '67': 'spring crocus',
#  '68': 'bearded iris',
#  '69': 'windflower',
#  '7': 'moon orchid',
#  '70': 'tree poppy',
#  '71': 'gazania',
#  '72': 'azalea',
#  '73': 'water lily',
#  '74': 'rose',
#  '75': 'thorn apple',
#  '76': 'morning glory',
#  '77': 'passion flower',
#  '78': 'lotus lotus',
#  '79': 'toad lily',
#  '8': 'bird of paradise',
#  '80': 'anthurium',
#  '81': 'frangipani',
#  '82': 'clematis',
#  '83': 'hibiscus',
#  '84': 'columbine',
#  '85': 'desert-rose',
#  '86': 'tree mallow',
#  '87': 'magnolia',
#  '88': 'cyclamen',
#  '89': 'watercress',
#  '9': 'monkshood',
#  '90': 'canna lily',
#  '91': 'hippeastrum',
#  '92': 'bee balm',
#  '93': 'ball moss',
#  '94': 'foxglove',
#  '95': 'bougainvillea',
#  '96': 'camellia',
#  '97': 'mallow',
#  '98': 'mexican petunia',
#  '99': 'bromelia'}

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %%
# TODO: Build and train your network
model = models.inception_v3(pretrained=True)

# %%
# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False

from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
                          ('transfers_fc1', nn.Linear(2048, 1024)),
                          ('transfers_relu1', nn.ReLU()),
                          ('transfer_dp1', nn.Dropout(0.25)), 
                          ('transfers_fc2', nn.Linear(1024, 102)),                                    
                          ('transfers_output', nn.LogSoftmax(dim=1))    
                          ]))
    
model.fc = classifier


use_cuda = True
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Training on device = " + str(device))

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.002)
model.to(device),
# Out:
# Training on device = cuda:0
# (Inception3(
#    (Conv2d_1a_3x3): BasicConv2d(
#      (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#      (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (Conv2d_2a_3x3): BasicConv2d(
#      (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#      (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (Conv2d_2b_3x3): BasicConv2d(
#      (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (Conv2d_3b_1x1): BasicConv2d(
#      (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (Conv2d_4a_3x3): BasicConv2d(
#      (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#      (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#    )
#    (Mixed_5b): InceptionA(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_1): BasicConv2d(
#        (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_2): BasicConv2d(
#        (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3): BasicConv2d(
#        (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_5c): InceptionA(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_1): BasicConv2d(
#        (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_2): BasicConv2d(
#        (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3): BasicConv2d(
#        (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_5d): InceptionA(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_1): BasicConv2d(
#        (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch5x5_2): BasicConv2d(
#        (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3): BasicConv2d(
#        (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6a): InceptionB(
#      (branch3x3): BasicConv2d(
#        (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3): BasicConv2d(
#        (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#        (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6b): InceptionC(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_1): BasicConv2d(
#        (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_2): BasicConv2d(
#        (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_3): BasicConv2d(
#        (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_1): BasicConv2d(
#        (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_2): BasicConv2d(
#        (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_3): BasicConv2d(
#        (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_4): BasicConv2d(
#        (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_5): BasicConv2d(
#        (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6c): InceptionC(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_1): BasicConv2d(
#        (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_2): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_3): BasicConv2d(
#        (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_1): BasicConv2d(
#        (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_2): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_3): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_4): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_5): BasicConv2d(
#        (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6d): InceptionC(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_1): BasicConv2d(
#        (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_2): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_3): BasicConv2d(
#        (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_1): BasicConv2d(
#        (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_2): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_3): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_4): BasicConv2d(
#        (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_5): BasicConv2d(
#        (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_6e): InceptionC(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_2): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7_3): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_2): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_3): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_4): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7dbl_5): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (AuxLogits): InceptionAux(
#      (conv0): BasicConv2d(
#        (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (conv1): BasicConv2d(
#        (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (fc): Linear(in_features=768, out_features=1000, bias=True)
#    )
#    (Mixed_7a): InceptionD(
#      (branch3x3_1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2): BasicConv2d(
#        (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#        (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7x3_1): BasicConv2d(
#        (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7x3_2): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7x3_3): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch7x7x3_4): BasicConv2d(
#        (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_7b): InceptionE(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_1): BasicConv2d(
#        (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2a): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2b): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3a): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3b): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (Mixed_7c): InceptionE(
#      (branch1x1): BasicConv2d(
#        (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_1): BasicConv2d(
#        (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2a): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3_2b): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_1): BasicConv2d(
#        (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_2): BasicConv2d(
#        (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3a): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch3x3dbl_3b): BasicConv2d(
#        (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#        (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#      (branch_pool): BasicConv2d(
#        (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (fc): Sequential(
#      (transfers_fc1): Linear(in_features=2048, out_features=1024, bias=True)
#      (transfers_relu1): ReLU()
#      (transfer_dp1): Dropout(p=0.25)
#      (transfers_fc2): Linear(in_features=1024, out_features=102, bias=True)
#      (transfers_output): LogSoftmax()
#    )
#  ),)

# %%
import numpy as np
epochs = 20
steps = 0
running_loss = 0
print_every = 5
test_loss_min = np.Inf # track change in validation loss



for epoch in range(epochs):
    for inputs, labels in trainloader:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        logps, aux = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in testloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    test_loss += batch_loss.item()
                    
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
            print (f'Epoch {epoch+1}/{epochs}... '
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(testloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(testloader):.3f}")
            running_loss = 0
            model.train()
            
            
            # calculate average losses
            #train_loss = train_loss/len(train_loader.dataset)
            test_loss = test_loss/len(testloader.dataset)

            # print training/validation statistics 
            #print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            #    epoch, train_loss, test_loss))

            # save model if validation loss has decreased
            if test_loss <= test_loss_min:
                print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
                test_loss_min,
                test_loss))
                
                checkpoint = {'input_size': 299,
                              'output_size':102,
                              'classifier': classifier,
                              'state_dict': model.state_dict()}
                
                torch.save(checkpoint, 'checkpoint.pt')
                test_loss_min = test_loss
# Out:
# Epoch 1/20... Train loss: 4.769.. Test loss: 4.612.. Test accuracy: 0.028
# Validation loss decreased (inf --> 0.073303).  Saving model ...
# Epoch 1/20... Train loss: 4.549.. Test loss: 4.481.. Test accuracy: 0.077
# Validation loss decreased (0.073303 --> 0.071219).  Saving model ...
# Epoch 1/20... Train loss: 4.431.. Test loss: 4.355.. Test accuracy: 0.096
# Validation loss decreased (0.071219 --> 0.069214).  Saving model ...
# Epoch 1/20... Train loss: 4.315.. Test loss: 4.256.. Test accuracy: 0.093
# Validation loss decreased (0.069214 --> 0.067639).  Saving model ...
# Epoch 1/20... Train loss: 4.390.. Test loss: 4.166.. Test accuracy: 0.143
# Validation loss decreased (0.067639 --> 0.066207).  Saving model ...
# Epoch 1/20... Train loss: 4.268.. Test loss: 4.063.. Test accuracy: 0.173
# Validation loss decreased (0.066207 --> 0.064576).  Saving model ...
# Epoch 1/20... Train loss: 4.183.. Test loss: 3.900.. Test accuracy: 0.169
# Validation loss decreased (0.064576 --> 0.061982).  Saving model ...
# Epoch 1/20... Train loss: 3.836.. Test loss: 3.783.. Test accuracy: 0.134
# Validation loss decreased (0.061982 --> 0.060114).  Saving model ...
# Epoch 1/20... Train loss: 3.844.. Test loss: 3.633.. Test accuracy: 0.244
# Validation loss decreased (0.060114 --> 0.057737).  Saving model ...
# Epoch 1/20... Train loss: 3.679.. Test loss: 3.413.. Test accuracy: 0.280
# Validation loss decreased (0.057737 --> 0.054235).  Saving model ...
# Epoch 1/20... Train loss: 3.516.. Test loss: 3.249.. Test accuracy: 0.281
# Validation loss decreased (0.054235 --> 0.051637).  Saving model ...
# Epoch 1/20... Train loss: 3.502.. Test loss: 3.078.. Test accuracy: 0.350
# Validation loss decreased (0.051637 --> 0.048911).  Saving model ...
# Epoch 1/20... Train loss: 3.254.. Test loss: 2.940.. Test accuracy: 0.368
# Validation loss decreased (0.048911 --> 0.046731).  Saving model ...
# Epoch 1/20... Train loss: 3.111.. Test loss: 2.914.. Test accuracy: 0.352
# Validation loss decreased (0.046731 --> 0.046305).  Saving model ...
# Epoch 1/20... Train loss: 3.056.. Test loss: 2.687.. Test accuracy: 0.408
# Validation loss decreased (0.046305 --> 0.042697).  Saving model ...
# Epoch 1/20... Train loss: 2.871.. Test loss: 2.607.. Test accuracy: 0.421
# Validation loss decreased (0.042697 --> 0.041433).  Saving model ...
# Epoch 1/20... Train loss: 2.961.. Test loss: 2.404.. Test accuracy: 0.478
# Validation loss decreased (0.041433 --> 0.038203).  Saving model ...
# Epoch 1/20... Train loss: 2.720.. Test loss: 2.444.. Test accuracy: 0.448
# Epoch 1/20... Train loss: 2.787.. Test loss: 2.261.. Test accuracy: 0.500
# Validation loss decreased (0.038203 --> 0.035939).  Saving model ...
# Epoch 1/20... Train loss: 2.605.. Test loss: 2.258.. Test accuracy: 0.450
# Validation loss decreased (0.035939 --> 0.035893).  Saving model ...
# Epoch 2/20... Train loss: 2.633.. Test loss: 2.284.. Test accuracy: 0.476
# Epoch 2/20... Train loss: 2.496.. Test loss: 2.132.. Test accuracy: 0.515
# Validation loss decreased (0.035893 --> 0.033890).  Saving model ...
# Epoch 2/20... Train loss: 2.393.. Test loss: 2.009.. Test accuracy: 0.517
# Validation loss decreased (0.033890 --> 0.031924).  Saving model ...
# Epoch 2/20... Train loss: 2.333.. Test loss: 1.966.. Test accuracy: 0.498
# Validation loss decreased (0.031924 --> 0.031247).  Saving model ...
# Epoch 2/20... Train loss: 2.444.. Test loss: 1.864.. Test accuracy: 0.577
# Validation loss decreased (0.031247 --> 0.029620).  Saving model ...
# Epoch 2/20... Train loss: 2.289.. Test loss: 1.869.. Test accuracy: 0.584
# Epoch 2/20... Train loss: 2.278.. Test loss: 1.732.. Test accuracy: 0.601
# Validation loss decreased (0.029620 --> 0.027528).  Saving model ...
# Epoch 2/20... Train loss: 2.175.. Test loss: 1.717.. Test accuracy: 0.560
# Validation loss decreased (0.027528 --> 0.027289).  Saving model ...
# Epoch 2/20... Train loss: 2.343.. Test loss: 1.670.. Test accuracy: 0.587
# Validation loss decreased (0.027289 --> 0.026547).  Saving model ...
# Epoch 2/20... Train loss: 2.063.. Test loss: 1.683.. Test accuracy: 0.603
# Epoch 2/20... Train loss: 1.935.. Test loss: 1.618.. Test accuracy: 0.602
# Validation loss decreased (0.026547 --> 0.025719).  Saving model ...
# Epoch 2/20... Train loss: 2.077.. Test loss: 1.575.. Test accuracy: 0.625
# Validation loss decreased (0.025719 --> 0.025033).  Saving model ...
# Epoch 2/20... Train loss: 2.167.. Test loss: 1.592.. Test accuracy: 0.629
# Epoch 2/20... Train loss: 2.127.. Test loss: 1.540.. Test accuracy: 0.612
# Validation loss decreased (0.025033 --> 0.024474).  Saving model ...
# Epoch 2/20... Train loss: 2.081.. Test loss: 1.463.. Test accuracy: 0.650
# Validation loss decreased (0.024474 --> 0.023256).  Saving model ...
# Epoch 2/20... Train loss: 1.863.. Test loss: 1.451.. Test accuracy: 0.642
# Validation loss decreased (0.023256 --> 0.023055).  Saving model ...
# Epoch 2/20... Train loss: 1.756.. Test loss: 1.369.. Test accuracy: 0.651
# Validation loss decreased (0.023055 --> 0.021753).  Saving model ...
# Epoch 2/20... Train loss: 1.969.. Test loss: 1.338.. Test accuracy: 0.688
# Validation loss decreased (0.021753 --> 0.021258).  Saving model ...
# Epoch 2/20... Train loss: 1.916.. Test loss: 1.384.. Test accuracy: 0.647
# Epoch 2/20... Train loss: 2.049.. Test loss: 1.456.. Test accuracy: 0.634
# Epoch 2/20... Train loss: 1.839.. Test loss: 1.347.. Test accuracy: 0.672
# Epoch 3/20... Train loss: 1.848.. Test loss: 1.345.. Test accuracy: 0.651
# Epoch 3/20... Train loss: 1.786.. Test loss: 1.348.. Test accuracy: 0.662
# Epoch 3/20... Train loss: 1.909.. Test loss: 1.400.. Test accuracy: 0.655
# Epoch 3/20... Train loss: 1.876.. Test loss: 1.307.. Test accuracy: 0.671
# Validation loss decreased (0.021258 --> 0.020770).  Saving model ...
# Epoch 3/20... Train loss: 1.880.. Test loss: 1.258.. Test accuracy: 0.670
# Validation loss decreased (0.020770 --> 0.019998).  Saving model ...
# Epoch 3/20... Train loss: 2.003.. Test loss: 1.323.. Test accuracy: 0.664
# Epoch 3/20... Train loss: 1.692.. Test loss: 1.270.. Test accuracy: 0.666
# Epoch 3/20... Train loss: 1.732.. Test loss: 1.228.. Test accuracy: 0.693
# Validation loss decreased (0.019998 --> 0.019522).  Saving model ...
# Epoch 3/20... Train loss: 1.863.. Test loss: 1.204.. Test accuracy: 0.696
# Validation loss decreased (0.019522 --> 0.019132).  Saving model ...
# Epoch 3/20... Train loss: 1.730.. Test loss: 1.183.. Test accuracy: 0.686
# Validation loss decreased (0.019132 --> 0.018808).  Saving model ...
# Epoch 3/20... Train loss: 1.804.. Test loss: 1.157.. Test accuracy: 0.693
# Validation loss decreased (0.018808 --> 0.018392).  Saving model ...
# Epoch 3/20... Train loss: 1.871.. Test loss: 1.150.. Test accuracy: 0.706
# Validation loss decreased (0.018392 --> 0.018273).  Saving model ...
# Epoch 3/20... Train loss: 1.842.. Test loss: 1.073.. Test accuracy: 0.726
# Validation loss decreased (0.018273 --> 0.017048).  Saving model ...
# Epoch 3/20... Train loss: 1.700.. Test loss: 1.143.. Test accuracy: 0.716
# Epoch 3/20... Train loss: 1.683.. Test loss: 1.180.. Test accuracy: 0.703
# Epoch 3/20... Train loss: 1.674.. Test loss: 1.057.. Test accuracy: 0.724
# Validation loss decreased (0.017048 --> 0.016791).  Saving model ...
# Epoch 3/20... Train loss: 1.694.. Test loss: 1.120.. Test accuracy: 0.708
# Epoch 3/20... Train loss: 1.521.. Test loss: 1.091.. Test accuracy: 0.715
# Epoch 3/20... Train loss: 1.673.. Test loss: 1.001.. Test accuracy: 0.752
# Validation loss decreased (0.016791 --> 0.015908).  Saving model ...
# Epoch 3/20... Train loss: 1.720.. Test loss: 1.054.. Test accuracy: 0.717
# Epoch 4/20... Train loss: 1.509.. Test loss: 1.036.. Test accuracy: 0.742
# Epoch 4/20... Train loss: 1.600.. Test loss: 1.114.. Test accuracy: 0.715
# Epoch 4/20... Train loss: 1.749.. Test loss: 0.958.. Test accuracy: 0.746
# Validation loss decreased (0.015908 --> 0.015227).  Saving model ...
# Epoch 4/20... Train loss: 1.627.. Test loss: 1.038.. Test accuracy: 0.738
# Epoch 4/20... Train loss: 1.577.. Test loss: 1.016.. Test accuracy: 0.747
# Epoch 4/20... Train loss: 1.627.. Test loss: 0.981.. Test accuracy: 0.758
# Epoch 4/20... Train loss: 1.510.. Test loss: 0.990.. Test accuracy: 0.748
# Epoch 4/20... Train loss: 1.496.. Test loss: 0.990.. Test accuracy: 0.739
# Epoch 4/20... Train loss: 1.630.. Test loss: 1.007.. Test accuracy: 0.753
# Epoch 4/20... Train loss: 1.537.. Test loss: 0.989.. Test accuracy: 0.742
# Epoch 4/20... Train loss: 1.819.. Test loss: 0.973.. Test accuracy: 0.761
# Epoch 4/20... Train loss: 1.472.. Test loss: 0.992.. Test accuracy: 0.741
# Epoch 4/20... Train loss: 1.452.. Test loss: 1.046.. Test accuracy: 0.731
# Epoch 4/20... Train loss: 1.649.. Test loss: 0.905.. Test accuracy: 0.764
# Validation loss decreased (0.015227 --> 0.014384).  Saving model ...
# Epoch 4/20... Train loss: 1.506.. Test loss: 0.902.. Test accuracy: 0.748
# Validation loss decreased (0.014384 --> 0.014340).  Saving model ...
# Epoch 4/20... Train loss: 1.538.. Test loss: 0.951.. Test accuracy: 0.737
# Epoch 4/20... Train loss: 1.501.. Test loss: 1.067.. Test accuracy: 0.717
# Epoch 4/20... Train loss: 1.502.. Test loss: 0.937.. Test accuracy: 0.770
# Epoch 4/20... Train loss: 1.514.. Test loss: 0.878.. Test accuracy: 0.756
# Validation loss decreased (0.014340 --> 0.013950).  Saving model ...
# Epoch 4/20... Train loss: 1.601.. Test loss: 0.925.. Test accuracy: 0.752
# Epoch 4/20... Train loss: 1.603.. Test loss: 0.901.. Test accuracy: 0.782
# Epoch 5/20... Train loss: 1.642.. Test loss: 0.993.. Test accuracy: 0.739
# Epoch 5/20... Train loss: 1.658.. Test loss: 0.886.. Test accuracy: 0.773
# Epoch 5/20... Train loss: 1.569.. Test loss: 0.835.. Test accuracy: 0.806
# Validation loss decreased (0.013950 --> 0.013275).  Saving model ...
# Epoch 5/20... Train loss: 1.501.. Test loss: 0.879.. Test accuracy: 0.778
# Epoch 5/20... Train loss: 1.365.. Test loss: 0.866.. Test accuracy: 0.770
# Epoch 5/20... Train loss: 1.554.. Test loss: 0.949.. Test accuracy: 0.747
# Epoch 5/20... Train loss: 1.589.. Test loss: 0.859.. Test accuracy: 0.781
# Epoch 5/20... Train loss: 1.517.. Test loss: 0.814.. Test accuracy: 0.811
# Validation loss decreased (0.013275 --> 0.012941).  Saving model ...
# Epoch 5/20... Train loss: 1.499.. Test loss: 0.900.. Test accuracy: 0.756
# Epoch 5/20... Train loss: 1.656.. Test loss: 0.889.. Test accuracy: 0.770
# Epoch 5/20... Train loss: 1.336.. Test loss: 0.938.. Test accuracy: 0.739
# Epoch 5/20... Train loss: 1.447.. Test loss: 0.863.. Test accuracy: 0.785
# Epoch 5/20... Train loss: 1.504.. Test loss: 0.851.. Test accuracy: 0.759
# Epoch 5/20... Train loss: 1.411.. Test loss: 0.898.. Test accuracy: 0.743
# Epoch 5/20... Train loss: 1.433.. Test loss: 0.815.. Test accuracy: 0.782
# Epoch 5/20... Train loss: 1.425.. Test loss: 0.771.. Test accuracy: 0.813
# Validation loss decreased (0.012941 --> 0.012258).  Saving model ...
# Epoch 5/20... Train loss: 1.481.. Test loss: 0.844.. Test accuracy: 0.787
# Epoch 5/20... Train loss: 1.449.. Test loss: 0.945.. Test accuracy: 0.744
# Epoch 5/20... Train loss: 1.668.. Test loss: 0.829.. Test accuracy: 0.777
# Epoch 5/20... Train loss: 1.437.. Test loss: 0.862.. Test accuracy: 0.769
# Epoch 5/20... Train loss: 1.587.. Test loss: 0.889.. Test accuracy: 0.770
# Epoch 6/20... Train loss: 1.440.. Test loss: 0.900.. Test accuracy: 0.763
# Epoch 6/20... Train loss: 1.512.. Test loss: 0.825.. Test accuracy: 0.801
# Epoch 6/20... Train loss: 1.424.. Test loss: 0.830.. Test accuracy: 0.792
# Epoch 6/20... Train loss: 1.509.. Test loss: 0.824.. Test accuracy: 0.766
# Epoch 6/20... Train loss: 1.332.. Test loss: 0.869.. Test accuracy: 0.755
# Epoch 6/20... Train loss: 1.538.. Test loss: 0.864.. Test accuracy: 0.770
# Epoch 6/20... Train loss: 1.430.. Test loss: 0.785.. Test accuracy: 0.787
# Epoch 6/20... Train loss: 1.694.. Test loss: 0.754.. Test accuracy: 0.808
# Validation loss decreased (0.012258 --> 0.011976).  Saving model ...
# Epoch 6/20... Train loss: 1.558.. Test loss: 0.785.. Test accuracy: 0.798
# Epoch 6/20... Train loss: 1.368.. Test loss: 0.813.. Test accuracy: 0.784
# Epoch 6/20... Train loss: 1.358.. Test loss: 0.815.. Test accuracy: 0.776
# Epoch 6/20... Train loss: 1.485.. Test loss: 0.854.. Test accuracy: 0.771
# Epoch 6/20... Train loss: 1.427.. Test loss: 0.808.. Test accuracy: 0.784
# Epoch 6/20... Train loss: 1.343.. Test loss: 0.757.. Test accuracy: 0.792
# Epoch 6/20... Train loss: 1.211.. Test loss: 0.711.. Test accuracy: 0.816
# Validation loss decreased (0.011976 --> 0.011304).  Saving model ...
# Epoch 6/20... Train loss: 1.417.. Test loss: 0.780.. Test accuracy: 0.790
# Epoch 6/20... Train loss: 1.349.. Test loss: 0.753.. Test accuracy: 0.793
# Epoch 6/20... Train loss: 1.661.. Test loss: 0.767.. Test accuracy: 0.785
# Epoch 6/20... Train loss: 1.224.. Test loss: 0.760.. Test accuracy: 0.798
# Epoch 6/20... Train loss: 1.383.. Test loss: 0.731.. Test accuracy: 0.805
# Epoch 7/20... Train loss: 1.316.. Test loss: 0.806.. Test accuracy: 0.785
# Epoch 7/20... Train loss: 1.395.. Test loss: 0.797.. Test accuracy: 0.781
# Epoch 7/20... Train loss: 1.432.. Test loss: 0.717.. Test accuracy: 0.814
# Epoch 7/20... Train loss: 1.366.. Test loss: 0.742.. Test accuracy: 0.803
# Epoch 7/20... Train loss: 1.443.. Test loss: 0.774.. Test accuracy: 0.794
# Epoch 7/20... Train loss: 1.334.. Test loss: 0.810.. Test accuracy: 0.782
# Epoch 7/20... Train loss: 1.496.. Test loss: 0.802.. Test accuracy: 0.784
# Epoch 7/20... Train loss: 1.314.. Test loss: 0.717.. Test accuracy: 0.805
# Epoch 7/20... Train loss: 1.414.. Test loss: 0.693.. Test accuracy: 0.809
# Validation loss decreased (0.011304 --> 0.011015).  Saving model ...
# Epoch 7/20... Train loss: 1.357.. Test loss: 0.694.. Test accuracy: 0.806
# Epoch 7/20... Train loss: 1.330.. Test loss: 0.715.. Test accuracy: 0.795
# Epoch 7/20... Train loss: 1.312.. Test loss: 0.670.. Test accuracy: 0.816
# Validation loss decreased (0.011015 --> 0.010649).  Saving model ...
# Epoch 7/20... Train loss: 1.316.. Test loss: 0.700.. Test accuracy: 0.798
# Epoch 7/20... Train loss: 1.325.. Test loss: 0.724.. Test accuracy: 0.799
# Epoch 7/20... Train loss: 1.249.. Test loss: 0.713.. Test accuracy: 0.808
# Epoch 7/20... Train loss: 1.389.. Test loss: 0.682.. Test accuracy: 0.814
# Epoch 7/20... Train loss: 1.312.. Test loss: 0.691.. Test accuracy: 0.814
# Epoch 7/20... Train loss: 1.402.. Test loss: 0.685.. Test accuracy: 0.833
# Epoch 7/20... Train loss: 1.164.. Test loss: 0.757.. Test accuracy: 0.780
# Epoch 7/20... Train loss: 1.345.. Test loss: 0.702.. Test accuracy: 0.805
# Epoch 7/20... Train loss: 1.283.. Test loss: 0.658.. Test accuracy: 0.824
# Validation loss decreased (0.010649 --> 0.010451).  Saving model ...
# Epoch 8/20... Train loss: 1.252.. Test loss: 0.690.. Test accuracy: 0.802
# Epoch 8/20... Train loss: 1.160.. Test loss: 0.724.. Test accuracy: 0.786
# Epoch 8/20... Train loss: 1.342.. Test loss: 0.653.. Test accuracy: 0.824
# Validation loss decreased (0.010451 --> 0.010378).  Saving model ...
# Epoch 8/20... Train loss: 1.275.. Test loss: 0.705.. Test accuracy: 0.806
# Epoch 8/20... Train loss: 1.270.. Test loss: 0.705.. Test accuracy: 0.804
# Epoch 8/20... Train loss: 1.428.. Test loss: 0.683.. Test accuracy: 0.812
# Epoch 8/20... Train loss: 1.311.. Test loss: 0.754.. Test accuracy: 0.784
# Epoch 8/20... Train loss: 1.332.. Test loss: 0.756.. Test accuracy: 0.774
# Epoch 8/20... Train loss: 1.389.. Test loss: 0.697.. Test accuracy: 0.808
# Epoch 8/20... Train loss: 1.365.. Test loss: 0.661.. Test accuracy: 0.823
# Epoch 8/20... Train loss: 1.457.. Test loss: 0.701.. Test accuracy: 0.804
# Epoch 8/20... Train loss: 1.271.. Test loss: 0.708.. Test accuracy: 0.796
# Epoch 8/20... Train loss: 1.390.. Test loss: 0.634.. Test accuracy: 0.837
# Validation loss decreased (0.010378 --> 0.010074).  Saving model ...
# Epoch 8/20... Train loss: 1.312.. Test loss: 0.694.. Test accuracy: 0.803
# Epoch 8/20... Train loss: 1.205.. Test loss: 0.691.. Test accuracy: 0.821
# Epoch 8/20... Train loss: 1.260.. Test loss: 0.630.. Test accuracy: 0.836
# Validation loss decreased (0.010074 --> 0.010009).  Saving model ...
# Epoch 8/20... Train loss: 1.330.. Test loss: 0.619.. Test accuracy: 0.843
# Validation loss decreased (0.010009 --> 0.009836).  Saving model ...
# Epoch 8/20... Train loss: 1.154.. Test loss: 0.682.. Test accuracy: 0.810
# Epoch 8/20... Train loss: 1.418.. Test loss: 0.691.. Test accuracy: 0.810
# Epoch 8/20... Train loss: 1.315.. Test loss: 0.679.. Test accuracy: 0.810
# Epoch 9/20... Train loss: 1.376.. Test loss: 0.697.. Test accuracy: 0.808
# Epoch 9/20... Train loss: 1.468.. Test loss: 0.710.. Test accuracy: 0.801
# Epoch 9/20... Train loss: 1.217.. Test loss: 0.678.. Test accuracy: 0.810
# Epoch 9/20... Train loss: 1.285.. Test loss: 0.673.. Test accuracy: 0.811
# Epoch 9/20... Train loss: 1.319.. Test loss: 0.668.. Test accuracy: 0.832
# Epoch 9/20... Train loss: 1.468.. Test loss: 0.723.. Test accuracy: 0.817
# Epoch 9/20... Train loss: 1.364.. Test loss: 0.700.. Test accuracy: 0.813
# Epoch 9/20... Train loss: 1.303.. Test loss: 0.654.. Test accuracy: 0.815
# Epoch 9/20... Train loss: 1.157.. Test loss: 0.635.. Test accuracy: 0.810
# Epoch 9/20... Train loss: 1.371.. Test loss: 0.727.. Test accuracy: 0.791
# Epoch 9/20... Train loss: 1.371.. Test loss: 0.691.. Test accuracy: 0.797
# Epoch 9/20... Train loss: 1.228.. Test loss: 0.694.. Test accuracy: 0.814
# Epoch 9/20... Train loss: 1.231.. Test loss: 0.665.. Test accuracy: 0.827
# Epoch 9/20... Train loss: 1.205.. Test loss: 0.648.. Test accuracy: 0.818
# Epoch 9/20... Train loss: 1.393.. Test loss: 0.669.. Test accuracy: 0.809
# Epoch 9/20... Train loss: 1.199.. Test loss: 0.698.. Test accuracy: 0.804
# Epoch 9/20... Train loss: 1.472.. Test loss: 0.672.. Test accuracy: 0.816
# Epoch 9/20... Train loss: 1.323.. Test loss: 0.738.. Test accuracy: 0.793
# Epoch 9/20... Train loss: 1.225.. Test loss: 0.682.. Test accuracy: 0.794
# Epoch 9/20... Train loss: 1.155.. Test loss: 0.663.. Test accuracy: 0.821
# Epoch 9/20... Train loss: 1.236.. Test loss: 0.673.. Test accuracy: 0.814
# Epoch 10/20... Train loss: 1.195.. Test loss: 0.734.. Test accuracy: 0.796
# Epoch 10/20... Train loss: 1.203.. Test loss: 0.702.. Test accuracy: 0.803
# Epoch 10/20... Train loss: 1.311.. Test loss: 0.624.. Test accuracy: 0.826
# Epoch 10/20... Train loss: 1.453.. Test loss: 0.643.. Test accuracy: 0.814
# Epoch 10/20... Train loss: 1.234.. Test loss: 0.666.. Test accuracy: 0.821
# Epoch 10/20... Train loss: 1.188.. Test loss: 0.657.. Test accuracy: 0.830
# Epoch 10/20... Train loss: 1.245.. Test loss: 0.629.. Test accuracy: 0.825
# Epoch 10/20... Train loss: 1.302.. Test loss: 0.627.. Test accuracy: 0.825
# Epoch 10/20... Train loss: 1.337.. Test loss: 0.651.. Test accuracy: 0.818
# Epoch 10/20... Train loss: 1.377.. Test loss: 0.652.. Test accuracy: 0.820
# Epoch 10/20... Train loss: 1.238.. Test loss: 0.674.. Test accuracy: 0.814
# Epoch 10/20... Train loss: 1.314.. Test loss: 0.635.. Test accuracy: 0.836
# Epoch 10/20... Train loss: 1.284.. Test loss: 0.619.. Test accuracy: 0.834
# Epoch 10/20... Train loss: 1.481.. Test loss: 0.624.. Test accuracy: 0.835
# Epoch 10/20... Train loss: 1.342.. Test loss: 0.626.. Test accuracy: 0.840
# Epoch 10/20... Train loss: 1.192.. Test loss: 0.666.. Test accuracy: 0.815
# Epoch 10/20... Train loss: 1.053.. Test loss: 0.637.. Test accuracy: 0.823
# Epoch 10/20... Train loss: 1.458.. Test loss: 0.614.. Test accuracy: 0.842
# Validation loss decreased (0.009836 --> 0.009757).  Saving model ...
# Epoch 10/20... Train loss: 1.279.. Test loss: 0.685.. Test accuracy: 0.808
# Epoch 10/20... Train loss: 1.324.. Test loss: 0.641.. Test accuracy: 0.820
# Epoch 10/20... Train loss: 1.368.. Test loss: 0.609.. Test accuracy: 0.835
# Validation loss decreased (0.009757 --> 0.009685).  Saving model ...
# Epoch 11/20... Train loss: 1.162.. Test loss: 0.614.. Test accuracy: 0.849
# Epoch 11/20... Train loss: 1.213.. Test loss: 0.710.. Test accuracy: 0.798
# Epoch 11/20... Train loss: 1.251.. Test loss: 0.715.. Test accuracy: 0.794
# Epoch 11/20... Train loss: 1.256.. Test loss: 0.659.. Test accuracy: 0.813
# Epoch 11/20... Train loss: 1.311.. Test loss: 0.635.. Test accuracy: 0.832
# Epoch 11/20... Train loss: 1.270.. Test loss: 0.700.. Test accuracy: 0.812
# Epoch 11/20... Train loss: 1.307.. Test loss: 0.692.. Test accuracy: 0.810
# Epoch 11/20... Train loss: 1.181.. Test loss: 0.642.. Test accuracy: 0.826
# Epoch 11/20... Train loss: 1.312.. Test loss: 0.645.. Test accuracy: 0.809
# Epoch 11/20... Train loss: 1.354.. Test loss: 0.642.. Test accuracy: 0.813
# Epoch 11/20... Train loss: 1.325.. Test loss: 0.631.. Test accuracy: 0.826
# Epoch 11/20... Train loss: 1.165.. Test loss: 0.583.. Test accuracy: 0.825
# Validation loss decreased (0.009685 --> 0.009272).  Saving model ...
# Epoch 11/20... Train loss: 1.579.. Test loss: 0.577.. Test accuracy: 0.841
# Validation loss decreased (0.009272 --> 0.009170).  Saving model ...
# Epoch 11/20... Train loss: 1.304.. Test loss: 0.621.. Test accuracy: 0.831
# Epoch 11/20... Train loss: 1.393.. Test loss: 0.630.. Test accuracy: 0.826
# Epoch 11/20... Train loss: 1.278.. Test loss: 0.610.. Test accuracy: 0.818
# Epoch 11/20... Train loss: 1.191.. Test loss: 0.632.. Test accuracy: 0.829
# Epoch 11/20... Train loss: 1.142.. Test loss: 0.647.. Test accuracy: 0.827
# Epoch 11/20... Train loss: 1.274.. Test loss: 0.663.. Test accuracy: 0.825
# Epoch 11/20... Train loss: 1.188.. Test loss: 0.644.. Test accuracy: 0.824
# Epoch 12/20... Train loss: 1.247.. Test loss: 0.699.. Test accuracy: 0.812
# Epoch 12/20... Train loss: 1.249.. Test loss: 0.631.. Test accuracy: 0.832
# Epoch 12/20... Train loss: 1.207.. Test loss: 0.610.. Test accuracy: 0.844
# Epoch 12/20... Train loss: 1.209.. Test loss: 0.595.. Test accuracy: 0.837
# Epoch 12/20... Train loss: 1.352.. Test loss: 0.646.. Test accuracy: 0.824
# Epoch 12/20... Train loss: 1.200.. Test loss: 0.641.. Test accuracy: 0.824
# Epoch 12/20... Train loss: 1.189.. Test loss: 0.601.. Test accuracy: 0.820
# Epoch 12/20... Train loss: 1.298.. Test loss: 0.613.. Test accuracy: 0.818
# Epoch 12/20... Train loss: 1.123.. Test loss: 0.576.. Test accuracy: 0.841
# Validation loss decreased (0.009170 --> 0.009150).  Saving model ...
# Epoch 12/20... Train loss: 1.281.. Test loss: 0.552.. Test accuracy: 0.853
# Validation loss decreased (0.009150 --> 0.008779).  Saving model ...
# Epoch 12/20... Train loss: 1.252.. Test loss: 0.581.. Test accuracy: 0.846
# Epoch 12/20... Train loss: 1.376.. Test loss: 0.666.. Test accuracy: 0.820
# Epoch 12/20... Train loss: 1.232.. Test loss: 0.709.. Test accuracy: 0.798
# Epoch 12/20... Train loss: 1.348.. Test loss: 0.664.. Test accuracy: 0.813
# Epoch 12/20... Train loss: 1.401.. Test loss: 0.650.. Test accuracy: 0.815
# Epoch 12/20... Train loss: 1.348.. Test loss: 0.614.. Test accuracy: 0.825
# Epoch 12/20... Train loss: 1.231.. Test loss: 0.615.. Test accuracy: 0.827
# Epoch 12/20... Train loss: 1.337.. Test loss: 0.604.. Test accuracy: 0.846
# Epoch 12/20... Train loss: 1.143.. Test loss: 0.595.. Test accuracy: 0.840
# Epoch 12/20... Train loss: 1.427.. Test loss: 0.585.. Test accuracy: 0.830
# Epoch 12/20... Train loss: 1.138.. Test loss: 0.562.. Test accuracy: 0.845
# Epoch 13/20... Train loss: 1.364.. Test loss: 0.574.. Test accuracy: 0.829
# Epoch 13/20... Train loss: 1.329.. Test loss: 0.607.. Test accuracy: 0.828
# Epoch 13/20... Train loss: 1.242.. Test loss: 0.618.. Test accuracy: 0.819
# Epoch 13/20... Train loss: 1.227.. Test loss: 0.582.. Test accuracy: 0.834
# Epoch 13/20... Train loss: 1.350.. Test loss: 0.604.. Test accuracy: 0.821
# Epoch 13/20... Train loss: 1.191.. Test loss: 0.605.. Test accuracy: 0.825
# Epoch 13/20... Train loss: 1.156.. Test loss: 0.610.. Test accuracy: 0.822
# Epoch 13/20... Train loss: 1.117.. Test loss: 0.579.. Test accuracy: 0.846
# Epoch 13/20... Train loss: 1.349.. Test loss: 0.589.. Test accuracy: 0.843
# Epoch 13/20... Train loss: 1.170.. Test loss: 0.614.. Test accuracy: 0.830
# Epoch 13/20... Train loss: 1.225.. Test loss: 0.619.. Test accuracy: 0.831
# Epoch 13/20... Train loss: 1.113.. Test loss: 0.616.. Test accuracy: 0.831
# Epoch 13/20... Train loss: 1.163.. Test loss: 0.598.. Test accuracy: 0.842
# Epoch 13/20... Train loss: 1.179.. Test loss: 0.595.. Test accuracy: 0.841
# Epoch 13/20... Train loss: 1.157.. Test loss: 0.593.. Test accuracy: 0.839
# Epoch 13/20... Train loss: 1.240.. Test loss: 0.621.. Test accuracy: 0.823
# Epoch 13/20... Train loss: 1.444.. Test loss: 0.615.. Test accuracy: 0.819
# Epoch 13/20... Train loss: 1.311.. Test loss: 0.621.. Test accuracy: 0.834
# Epoch 13/20... Train loss: 1.314.. Test loss: 0.628.. Test accuracy: 0.831
# Epoch 13/20... Train loss: 1.257.. Test loss: 0.574.. Test accuracy: 0.848
# Epoch 14/20... Train loss: 1.246.. Test loss: 0.605.. Test accuracy: 0.833
# Epoch 14/20... Train loss: 1.138.. Test loss: 0.624.. Test accuracy: 0.818
# Epoch 14/20... Train loss: 1.275.. Test loss: 0.575.. Test accuracy: 0.846
# Epoch 14/20... Train loss: 1.301.. Test loss: 0.627.. Test accuracy: 0.833
# Epoch 14/20... Train loss: 1.285.. Test loss: 0.645.. Test accuracy: 0.824
# Epoch 14/20... Train loss: 1.269.. Test loss: 0.572.. Test accuracy: 0.840
# Epoch 14/20... Train loss: 1.268.. Test loss: 0.558.. Test accuracy: 0.850
# Epoch 14/20... Train loss: 1.193.. Test loss: 0.572.. Test accuracy: 0.826
# Epoch 14/20... Train loss: 1.138.. Test loss: 0.582.. Test accuracy: 0.846
# Epoch 14/20... Train loss: 1.318.. Test loss: 0.584.. Test accuracy: 0.839
# Epoch 14/20... Train loss: 1.143.. Test loss: 0.606.. Test accuracy: 0.831
# Epoch 14/20... Train loss: 1.188.. Test loss: 0.583.. Test accuracy: 0.848
# Epoch 14/20... Train loss: 1.136.. Test loss: 0.569.. Test accuracy: 0.846
# Epoch 14/20... Train loss: 1.338.. Test loss: 0.604.. Test accuracy: 0.827
# Epoch 14/20... Train loss: 1.075.. Test loss: 0.574.. Test accuracy: 0.853
# Epoch 14/20... Train loss: 1.275.. Test loss: 0.567.. Test accuracy: 0.838
# Epoch 14/20... Train loss: 1.215.. Test loss: 0.568.. Test accuracy: 0.838
# Epoch 14/20... Train loss: 1.274.. Test loss: 0.610.. Test accuracy: 0.835
# Epoch 14/20... Train loss: 1.348.. Test loss: 0.644.. Test accuracy: 0.825
# Epoch 14/20... Train loss: 1.310.. Test loss: 0.599.. Test accuracy: 0.840
# Epoch 14/20... Train loss: 1.320.. Test loss: 0.568.. Test accuracy: 0.859
# Epoch 15/20... Train loss: 1.214.. Test loss: 0.641.. Test accuracy: 0.832
# Epoch 15/20... Train loss: 1.323.. Test loss: 0.614.. Test accuracy: 0.839
# Epoch 15/20... Train loss: 1.295.. Test loss: 0.605.. Test accuracy: 0.831
# Epoch 15/20... Train loss: 1.180.. Test loss: 0.624.. Test accuracy: 0.820
# Epoch 15/20... Train loss: 1.287.. Test loss: 0.624.. Test accuracy: 0.824
# Epoch 15/20... Train loss: 1.235.. Test loss: 0.583.. Test accuracy: 0.832
# Epoch 15/20... Train loss: 1.295.. Test loss: 0.575.. Test accuracy: 0.845
# Epoch 15/20... Train loss: 1.125.. Test loss: 0.580.. Test accuracy: 0.852
# Epoch 15/20... Train loss: 1.238.. Test loss: 0.572.. Test accuracy: 0.851
# Epoch 15/20... Train loss: 1.140.. Test loss: 0.544.. Test accuracy: 0.837
# Validation loss decreased (0.008779 --> 0.008639).  Saving model ...
# Epoch 15/20... Train loss: 1.353.. Test loss: 0.559.. Test accuracy: 0.838
# Epoch 15/20... Train loss: 1.244.. Test loss: 0.564.. Test accuracy: 0.843
# Epoch 15/20... Train loss: 1.190.. Test loss: 0.549.. Test accuracy: 0.852
# Epoch 15/20... Train loss: 1.166.. Test loss: 0.555.. Test accuracy: 0.851
# Epoch 15/20... Train loss: 1.343.. Test loss: 0.553.. Test accuracy: 0.853
# Epoch 15/20... Train loss: 1.154.. Test loss: 0.622.. Test accuracy: 0.828
# Epoch 15/20... Train loss: 1.428.. Test loss: 0.647.. Test accuracy: 0.813
# Epoch 15/20... Train loss: 1.259.. Test loss: 0.635.. Test accuracy: 0.831
# Epoch 15/20... Train loss: 1.260.. Test loss: 0.585.. Test accuracy: 0.853
# Epoch 15/20... Train loss: 1.221.. Test loss: 0.585.. Test accuracy: 0.853
# Epoch 15/20... Train loss: 1.169.. Test loss: 0.596.. Test accuracy: 0.832
# Epoch 16/20... Train loss: 1.104.. Test loss: 0.596.. Test accuracy: 0.831
# Epoch 16/20... Train loss: 1.080.. Test loss: 0.574.. Test accuracy: 0.849
# Epoch 16/20... Train loss: 1.087.. Test loss: 0.552.. Test accuracy: 0.851
# Epoch 16/20... Train loss: 1.311.. Test loss: 0.543.. Test accuracy: 0.849
# Validation loss decreased (0.008639 --> 0.008636).  Saving model ...
# Epoch 16/20... Train loss: 1.187.. Test loss: 0.557.. Test accuracy: 0.831
# Epoch 16/20... Train loss: 1.184.. Test loss: 0.597.. Test accuracy: 0.833
# Epoch 16/20... Train loss: 1.128.. Test loss: 0.600.. Test accuracy: 0.847
# Epoch 16/20... Train loss: 1.326.. Test loss: 0.572.. Test accuracy: 0.844
# Epoch 16/20... Train loss: 1.325.. Test loss: 0.581.. Test accuracy: 0.841
# Epoch 16/20... Train loss: 1.252.. Test loss: 0.559.. Test accuracy: 0.847
# Epoch 16/20... Train loss: 1.266.. Test loss: 0.589.. Test accuracy: 0.848
# Epoch 16/20... Train loss: 1.198.. Test loss: 0.627.. Test accuracy: 0.835
# Epoch 16/20... Train loss: 1.234.. Test loss: 0.590.. Test accuracy: 0.852
# Epoch 16/20... Train loss: 1.278.. Test loss: 0.561.. Test accuracy: 0.849
# Epoch 16/20... Train loss: 1.253.. Test loss: 0.549.. Test accuracy: 0.843
# Epoch 16/20... Train loss: 1.332.. Test loss: 0.595.. Test accuracy: 0.843
# Epoch 16/20... Train loss: 1.198.. Test loss: 0.610.. Test accuracy: 0.832
# Epoch 16/20... Train loss: 1.200.. Test loss: 0.558.. Test accuracy: 0.853
# Epoch 16/20... Train loss: 1.096.. Test loss: 0.544.. Test accuracy: 0.848
# Epoch 16/20... Train loss: 1.317.. Test loss: 0.561.. Test accuracy: 0.847
# Epoch 17/20... Train loss: 1.020.. Test loss: 0.545.. Test accuracy: 0.858
# Epoch 17/20... Train loss: 1.304.. Test loss: 0.543.. Test accuracy: 0.847
# Validation loss decreased (0.008636 --> 0.008626).  Saving model ...
# Epoch 17/20... Train loss: 1.255.. Test loss: 0.569.. Test accuracy: 0.836
# Epoch 17/20... Train loss: 1.158.. Test loss: 0.604.. Test accuracy: 0.833
# Epoch 17/20... Train loss: 1.327.. Test loss: 0.568.. Test accuracy: 0.840
# Epoch 17/20... Train loss: 1.285.. Test loss: 0.581.. Test accuracy: 0.838
# Epoch 17/20... Train loss: 1.184.. Test loss: 0.574.. Test accuracy: 0.843
# Epoch 17/20... Train loss: 1.167.. Test loss: 0.560.. Test accuracy: 0.838
# Epoch 17/20... Train loss: 1.235.. Test loss: 0.566.. Test accuracy: 0.845
# Epoch 17/20... Train loss: 1.282.. Test loss: 0.603.. Test accuracy: 0.840
# Epoch 17/20... Train loss: 1.173.. Test loss: 0.603.. Test accuracy: 0.842
# Epoch 17/20... Train loss: 1.177.. Test loss: 0.592.. Test accuracy: 0.831
# Epoch 17/20... Train loss: 1.286.. Test loss: 0.589.. Test accuracy: 0.836
# Epoch 17/20... Train loss: 1.166.. Test loss: 0.573.. Test accuracy: 0.837
# Epoch 17/20... Train loss: 1.296.. Test loss: 0.582.. Test accuracy: 0.838
# Epoch 17/20... Train loss: 1.019.. Test loss: 0.559.. Test accuracy: 0.851
# Epoch 17/20... Train loss: 1.259.. Test loss: 0.539.. Test accuracy: 0.860
# Validation loss decreased (0.008626 --> 0.008574).  Saving model ...
# Epoch 17/20... Train loss: 1.172.. Test loss: 0.567.. Test accuracy: 0.850
# Epoch 17/20... Train loss: 1.301.. Test loss: 0.596.. Test accuracy: 0.835
# Epoch 17/20... Train loss: 1.121.. Test loss: 0.616.. Test accuracy: 0.828
# Epoch 17/20... Train loss: 1.392.. Test loss: 0.562.. Test accuracy: 0.838
# Epoch 18/20... Train loss: 1.335.. Test loss: 0.609.. Test accuracy: 0.823
# Epoch 18/20... Train loss: 1.226.. Test loss: 0.635.. Test accuracy: 0.814
# Epoch 18/20... Train loss: 1.227.. Test loss: 0.569.. Test accuracy: 0.850
# Epoch 18/20... Train loss: 1.150.. Test loss: 0.563.. Test accuracy: 0.847
# Epoch 18/20... Train loss: 1.268.. Test loss: 0.592.. Test accuracy: 0.834
# Epoch 18/20... Train loss: 1.099.. Test loss: 0.599.. Test accuracy: 0.841
# Epoch 18/20... Train loss: 1.138.. Test loss: 0.584.. Test accuracy: 0.844
# Epoch 18/20... Train loss: 1.247.. Test loss: 0.537.. Test accuracy: 0.857
# Validation loss decreased (0.008574 --> 0.008536).  Saving model ...
# Epoch 18/20... Train loss: 1.295.. Test loss: 0.571.. Test accuracy: 0.847
# Epoch 18/20... Train loss: 1.201.. Test loss: 0.591.. Test accuracy: 0.840
# Epoch 18/20... Train loss: 1.099.. Test loss: 0.603.. Test accuracy: 0.838
# Epoch 18/20... Train loss: 1.267.. Test loss: 0.551.. Test accuracy: 0.849
# Epoch 18/20... Train loss: 1.204.. Test loss: 0.537.. Test accuracy: 0.851
# Epoch 18/20... Train loss: 1.385.. Test loss: 0.561.. Test accuracy: 0.845
# Epoch 18/20... Train loss: 1.144.. Test loss: 0.565.. Test accuracy: 0.843
# Epoch 18/20... Train loss: 1.163.. Test loss: 0.562.. Test accuracy: 0.846
# Epoch 18/20... Train loss: 1.074.. Test loss: 0.550.. Test accuracy: 0.859
# Epoch 18/20... Train loss: 1.146.. Test loss: 0.566.. Test accuracy: 0.848
# Epoch 18/20... Train loss: 1.201.. Test loss: 0.584.. Test accuracy: 0.839
# Epoch 18/20... Train loss: 1.222.. Test loss: 0.591.. Test accuracy: 0.825
# Epoch 19/20... Train loss: 1.340.. Test loss: 0.560.. Test accuracy: 0.842
# Epoch 19/20... Train loss: 1.176.. Test loss: 0.592.. Test accuracy: 0.829
# Epoch 19/20... Train loss: 1.359.. Test loss: 0.578.. Test accuracy: 0.846
# Epoch 19/20... Train loss: 1.305.. Test loss: 0.613.. Test accuracy: 0.821
# Epoch 19/20... Train loss: 1.303.. Test loss: 0.663.. Test accuracy: 0.819
# Epoch 19/20... Train loss: 1.237.. Test loss: 0.592.. Test accuracy: 0.831
# Epoch 19/20... Train loss: 1.238.. Test loss: 0.550.. Test accuracy: 0.844
# Epoch 19/20... Train loss: 1.286.. Test loss: 0.550.. Test accuracy: 0.845
# Epoch 19/20... Train loss: 1.146.. Test loss: 0.578.. Test accuracy: 0.851
# Epoch 19/20... Train loss: 1.400.. Test loss: 0.564.. Test accuracy: 0.851
# Epoch 19/20... Train loss: 1.292.. Test loss: 0.535.. Test accuracy: 0.859
# Validation loss decreased (0.008536 --> 0.008495).  Saving model ...
# Epoch 19/20... Train loss: 1.136.. Test loss: 0.529.. Test accuracy: 0.844
# Validation loss decreased (0.008495 --> 0.008402).  Saving model ...
# Epoch 19/20... Train loss: 1.179.. Test loss: 0.529.. Test accuracy: 0.857
# Epoch 19/20... Train loss: 0.943.. Test loss: 0.552.. Test accuracy: 0.848
# Epoch 19/20... Train loss: 1.125.. Test loss: 0.545.. Test accuracy: 0.850
# Epoch 19/20... Train loss: 1.149.. Test loss: 0.542.. Test accuracy: 0.854
# Epoch 19/20... Train loss: 1.237.. Test loss: 0.521.. Test accuracy: 0.858
# Validation loss decreased (0.008402 --> 0.008274).  Saving model ...
# Epoch 19/20... Train loss: 1.168.. Test loss: 0.585.. Test accuracy: 0.849
# Epoch 19/20... Train loss: 1.290.. Test loss: 0.570.. Test accuracy: 0.857
# Epoch 19/20... Train loss: 1.202.. Test loss: 0.568.. Test accuracy: 0.846
# Epoch 19/20... Train loss: 1.167.. Test loss: 0.573.. Test accuracy: 0.835
# Epoch 20/20... Train loss: 1.136.. Test loss: 0.557.. Test accuracy: 0.841
# Epoch 20/20... Train loss: 1.190.. Test loss: 0.547.. Test accuracy: 0.845
# Epoch 20/20... Train loss: 1.102.. Test loss: 0.559.. Test accuracy: 0.855
# Epoch 20/20... Train loss: 1.212.. Test loss: 0.569.. Test accuracy: 0.850
# Epoch 20/20... Train loss: 1.038.. Test loss: 0.566.. Test accuracy: 0.849
# Epoch 20/20... Train loss: 1.099.. Test loss: 0.574.. Test accuracy: 0.831
# Epoch 20/20... Train loss: 1.286.. Test loss: 0.531.. Test accuracy: 0.844
# Epoch 20/20... Train loss: 1.385.. Test loss: 0.539.. Test accuracy: 0.846
# Epoch 20/20... Train loss: 1.312.. Test loss: 0.584.. Test accuracy: 0.835
# Epoch 20/20... Train loss: 1.138.. Test loss: 0.572.. Test accuracy: 0.837
# Epoch 20/20... Train loss: 1.173.. Test loss: 0.586.. Test accuracy: 0.839
# Epoch 20/20... Train loss: 1.267.. Test loss: 0.557.. Test accuracy: 0.853
# Epoch 20/20... Train loss: 1.350.. Test loss: 0.565.. Test accuracy: 0.844
# Epoch 20/20... Train loss: 1.134.. Test loss: 0.592.. Test accuracy: 0.842
# Epoch 20/20... Train loss: 1.358.. Test loss: 0.586.. Test accuracy: 0.847
# Epoch 20/20... Train loss: 1.085.. Test loss: 0.551.. Test accuracy: 0.852
# Epoch 20/20... Train loss: 1.154.. Test loss: 0.547.. Test accuracy: 0.844
# Epoch 20/20... Train loss: 1.233.. Test loss: 0.553.. Test accuracy: 0.854
# Epoch 20/20... Train loss: 1.181.. Test loss: 0.542.. Test accuracy: 0.841
# Epoch 20/20... Train loss: 1.340.. Test loss: 0.536.. Test accuracy: 0.854
# Epoch 20/20... Train loss: 1.251.. Test loss: 0.532.. Test accuracy: 0.849

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def load_checkpoint(filepath):
  checkpoint = torch.load(filepath)  
  model = models.inception_v3()
  model.fc = checkpoint['classifier']  
  model.load_state_dict(checkpoint['state_dict'])
  
  return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image,target_size=(299, 299)):
  
  #image = PIL.Image.open(image)
  image = Image.open(image)
  
  #if image.mode != 'RGB':
  #  image = image.convert("RGB")

  # Resize the input image nad preprocess it.
  image = T.Resize(target_size)(image)
  image = T.CenterCrop(299)(image)  
  image = T.ToTensor()(image)
  
  # Convert to Torch.Tensor and normalize.
  image = T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])(image)
  

  # Add batch_size axis.
  image = image[None]

  #return torch.autograd(image)
  return image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()   
    
    ax.imshow(image)
    #fig.suptitle('Main title')
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model = load_checkpoint(model)
    model.to(device)
    model.eval()

    image = process_image(image_path)
    img = image.to(device)

    result = model(img).topk(5)

    probs = torch.nn.functional.softmax(result[0].data, dim=1).cpu().numpy()[0]
    classes = list(result[1].data.cpu().numpy()[0]) 
    classes = [str(item) for item in classes]
    
    return probs, classes

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Testing on device = " + str(device))

#image_path = 'flower_data/valid/1/image_06739.jpg'
#image_path = 'flower_data/valid/29/image_04097.jpg'
image_path = 'ROSE.jpg'
model_ckp = 'checkpoint.pt'

probs, classes = predict(image_path,model_ckp)

print(probs)
print(classes)
# Out:
# Testing on device = cuda:0
# [0.42926508 0.42501408 0.05040677 0.05028825 0.04502582]
# ['53', '74', '64', '10', '13']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the validation accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

image = Image.open(image_path)
imshow(image)


label = []
for cat_to_name[0] in classes:
  label.append(cat_to_name[cat_to_name[0]])

print(probs)
print(label)
# Out:
# [0.42926508 0.42501408 0.05040677 0.05028825 0.04502582]
# ['primula', 'rose', 'silverbush', 'globe thistle', 'king protea']

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))
  
configure_plotly_browser_state()



from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go

init_notebook_mode(connected=True)

data = [go.Bar(x=label,
            y=probs)]
            

iplot(data, filename='horizontal-bar')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="979c7dab-fc73-481b-a2e4-12a0a4ff852f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("979c7dab-fc73-481b-a2e4-12a0a4ff852f", [{"type": "bar", "x": ["primula", "rose", "silverbush", "globe thistle", "king protea"], "y": [0.4292650818824768, 0.42501407861709595, 0.050406765192747116, 0.05028825253248215, 0.04502582177519798]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
from google.colab import files

files.download('checkpoint.pt')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-27-c8f48e24129b> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 files.download('checkpoint.pt')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: TypeError: Falha ao buscar
